# %% [markdown]
# # Mesclando categorias administrativas

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("dados_ies_sem_nan_sem_privadas_especial_utf8.csv", index_col=0, encoding="latin-1")

for c in range(len(df["TIPO_CATEGORIA_ADM"])):
  if df.iat[c, 2] == "PÃºblica Municipal":
    df.iat[c, 2] = "PÃºblica Estadual"

for c in range(len(df["TIPO_CATEGORIA_ADM"])):
  if df.iat[c, 2] == "PÃºblica Estadual":
    df.iat[c, 2] = "Sub-Nacional"
  if df.iat[c, 2] == "PÃºblica Federal":
    df.iat[c, 2] = "Nacional"

df.to_csv("dados_ies_novas_categorias_utf8.csv", encoding="utf8")
print(df)
# Out:
#       NUM_CURSOS  CODIGO_IES TIPO_CATEGORIA_ADM        REGIAO  \
# 0            114           1           Nacional  Centro-Oeste
# 1            149           2           Nacional  Centro-Oeste
# 2            116           3           Nacional      Nordeste
# 3            107           4           Nacional         Norte
# 4            100           5           Nacional      Nordeste
# ...          ...         ...                ...           ...
# 2601           2       23700       Sub-Nacional       Sudeste
# 2602           2       23705       Sub-Nacional       Sudeste
# 2603           1       23713       Sub-Nacional       Sudeste
# 2605           1       23867       Sub-Nacional       Sudeste
# 2607           1       24672       Sub-Nacional       Sudeste
#
#                     UF  DEFICIENCIA_FISICA  DEFICIENCIA_AUDITIVA  \
# 0          Mato Grosso                92.0                  58.0
# 1     Distrito Federal                39.0                  32.0
# 2              Sergipe               190.0                  56.0
# 3             Amazonas                64.0                  33.0
# 4               PiauÃ­               137.0                  50.0
# ...                ...                 ...                   ...
# 2601        SÃ£o Paulo                 0.0                   0.0
# 2602        SÃ£o Paulo                 1.0                   0.0
# 2603    Rio de Janeiro                 1.0                   0.0
# 2605        SÃ£o Paulo                 1.0                   0.0
# 2607        SÃ£o Paulo                 1.0                   0.0
#
#       DEFICIENCIA_VISUAL  DEFICIENCIA_COGNITIVA  DEFICIENCIA_MULTIPLA  \
# 0                   44.0                   17.0                   2.0
# 1                   27.0                   32.0                   8.0
# 2                   94.0                   16.0                   2.0
# 3                   54.0                   60.0                   2.0
# 4                   73.0                   36.0                   3.0
# ...                  ...                    ...                   ...
# 2601                 1.0                    0.0                   0.0
# 2602                 0.0                    0.0                   0.0
# 2603                 0.0                    1.0                   0.0
# 2605                 0.0                    0.0                   0.0
# 2607                 0.0                    0.0                   0.0
#
#       RECURSOS_DEF_FISICA  RECURSOS_DEF_VISUAL  RECURSOS_DEF_AUDITIVA  \
# 0                0.271930             0.429825               0.938596
# 1                2.778523             4.167785               3.704698
# 2                0.775862             1.215517               1.793103
# 3                0.000000             0.000000               0.719626
# 4                4.200000             5.880000               5.880000
# ...                   ...                  ...                    ...
# 2601             0.000000             0.500000               0.000000
# 2602             0.000000             0.000000               0.000000
# 2603             0.000000             0.000000               0.000000
# 2605             2.000000             2.000000               2.000000
# 2607             3.000000             4.000000               3.000000
#
#       RECURSOS_DEF_COGNITIVA  RECURSOS_DEF_MULTIPLA
# 0                   0.201754               0.201754
# 1                   1.852349               1.852349
# 2                   0.534483               0.534483
# 3                   0.000000               0.000000
# 4                   2.520000               2.520000
# ...                      ...                    ...
# 2601                0.000000               0.000000
# 2602                0.000000               0.000000
# 2603                0.000000               0.000000
# 2605                1.000000               1.000000
# 2607                2.000000               2.000000
#
# [235 rows x 15 columns]

# %% [markdown]
# # Gerando categorias por quantidade de recursos

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("dados_ies_sem_nan_sem_privadas_especial_utf8.csv", index_col=0, encoding="latin-1")
df.head()
# Out:
#    NUM_CURSOS  CODIGO_IES TIPO_CATEGORIA_ADM        REGIAO                UF  \
# 0         114           1   PÃºblica Federal  Centro-Oeste       Mato Grosso
# 1         149           2   PÃºblica Federal  Centro-Oeste  Distrito Federal
# 2         116           3   PÃºblica Federal      Nordeste           Sergipe
# 3         107           4   PÃºblica Federal         Norte          Amazonas
# 4         100           5   PÃºblica Federal      Nordeste            PiauÃ­
#
#    DEFICIENCIA_FISICA  DEFICIENCIA_AUDITIVA  DEFICIENCIA_VISUAL  \
# 0                92.0                  58.0                44.0
# 1                39.0                  32.0                27.0
# 2               190.0                  56.0                94.0
# 3                64.0                  33.0                54.0
# 4               137.0                  50.0                73.0
#
#    DEFICIENCIA_COGNITIVA  DEFICIENCIA_MULTIPLA  RECURSOS_DEF_FISICA  \
# 0                   17.0                   2.0             0.271930
# 1                   32.0                   8.0             2.778523
# 2                   16.0                   2.0             0.775862
# 3                   60.0                   2.0             0.000000
# 4                   36.0                   3.0             4.200000
#
#    RECURSOS_DEF_VISUAL  RECURSOS_DEF_AUDITIVA  RECURSOS_DEF_COGNITIVA  \
# 0             0.429825               0.938596                0.201754
# 1             4.167785               3.704698                1.852349
# 2             1.215517               1.793103                0.534483
# 3             0.000000               0.719626                0.000000
# 4             5.880000               5.880000                2.520000
#
#    RECURSOS_DEF_MULTIPLA
# 0               0.201754
# 1               1.852349
# 2               0.534483
# 3               0.000000
# 4               2.520000

# %%
# Procurando quantidades de recursos por IES
print("Qtd máxima: ")
print("RECURSOS_DEF_FISICA: ", df["RECURSOS_DEF_FISICA"].max())
print("RECURSOS_DEF_VISUAL: ", df["RECURSOS_DEF_VISUAL"].max())
print("RECURSOS_DEF_AUDITIVA: ", df["RECURSOS_DEF_AUDITIVA"].max())
print("RECURSOS_DEF_MULTIPLA: ", df["RECURSOS_DEF_MULTIPLA"].max())
print("RECURSOS_DEF_COGNITIVA: ", df["RECURSOS_DEF_COGNITIVA"].max())
print("\nQtd mínima: ")
print("RECURSOS_DEF_FISICA: ", df["RECURSOS_DEF_FISICA"].min())
print("RECURSOS_DEF_VISUAL: ", df["RECURSOS_DEF_VISUAL"].min())
print("RECURSOS_DEF_AUDITIVA: ", df["RECURSOS_DEF_AUDITIVA"].min())
print("RECURSOS_DEF_MULTIPLA: ", df["RECURSOS_DEF_MULTIPLA"].min())
print("RECURSOS_DEF_COGNITIVA: ", df["RECURSOS_DEF_COGNITIVA"].min())
# Out:
# Qtd máxima:
# RECURSOS_DEF_FISICA:  6.0
# RECURSOS_DEF_VISUAL:  9.0
# RECURSOS_DEF_AUDITIVA:  8.0
# RECURSOS_DEF_MULTIPLA:  4.0
# RECURSOS_DEF_COGNITIVA:  4.0
#
# Qtd mínima:
# RECURSOS_DEF_FISICA:  0.0
# RECURSOS_DEF_VISUAL:  0.0
# RECURSOS_DEF_AUDITIVA:  0.0
# RECURSOS_DEF_MULTIPLA:  0.0
# RECURSOS_DEF_COGNITIVA:  0.0

# %%
#df.head()
df.shape
# Out:
# (235, 15)

# %%
# Criando categorias baseadas em recursos.
# Recursos mínimos ou sem recursos = 0 - 2
# Recursos médios = 3 - 6
# Recursos altos = 6 - 9

#df["RECURSOS_DEF_FISICA"] = df["RECURSOS_DEF_FISICA"].astype(str)

from decimal import Decimal
df = pd.read_csv("dados_ies_sem_nan_sem_privadas_especial_utf8.csv", index_col=0, encoding="latin-1")

recursosFisicaClasses = []
recursosAuditivaClasses = []
recursosVisualClasses = []
recursosMultiplaClasses = []
recursosCognitivaClasses = []

classe0 = 0
classe1 = 0
classe2 = 0

for r in range(len(df["RECURSOS_DEF_FISICA"])):
  if df.iat[r, 10] <= 0.3:
    recursosFisicaClasses.append(0)
    #classe0 += 1
  elif df.iat[r, 10] > 0.3 and df.iat[r, 10] <= 1.8:
    recursosFisicaClasses.append(1)
    #classe1 += 1
  elif df.iat[r, 10] > 1.8:
    recursosFisicaClasses.append(2)
    #classe2 += 1

df["CLASSES_DEF_FISICA"] = recursosFisicaClasses

i = 0

for r in range(len(df["RECURSOS_DEF_VISUAL"])):
  #i += 1
  if df.iat[r, 11] <= 0.3:
    recursosVisualClasses.append(0)
    #classe0 += 1
  if df.iat[r, 11] > 0.3 and df.iat[r, 10] <= 1.85:
    recursosVisualClasses.append(1)
    #classe1 += 1
  if df.iat[r, 11] > 1.85:
    recursosVisualClasses.append(2)
    #classe2 += 1

df["CLASSES_DEF_VISUAL"] = recursosVisualClasses

'''for r in range(len(df["RECURSOS_DEF_AUDITIVA"])):
  if df.iat[r, 12] <= 1:
    print(df.iat[r,12])
    recursosAuditivaClasses.append(0)
    classe0 += 1
  if df.iat[r, 12] > 1 and df.iat[r, 10] <= 3:
    print(df.iat[r,12])
    recursosAuditivaClasses.append(1)
    classe1 += 1
  if df.iat[r, 12] > 3:
    print(df.iat[r,12])
    recursosAuditivaClasses.append(2)
    classe2 += 1'''


'''for r in range(len(df["RECURSOS_DEF_COGNITIVA"])):
  if df.iat[r, 13] <= .5:
    #print(df.iat[r,13])
    recursosCognitivaClasses.append(0)
    classe0 += 1
  if df.iat[r, 13] > 1 and df.iat[r, 10] <= 2:
    #print(df.iat[r,13])
    recursosCognitivaClasses.append(1)
    classe1 += 1
  if df.iat[r, 13] > 1.5:
    #print(df.iat[r,13])
    recursosCognitivaClasses.append(2)
    classe2 += 1'''

#df["CLASSES_DEF_AUDITIVA"] = recursosAuditivaClasses

df.to_csv("dados_ies_recursos_categorias_utf8.csv", encoding="utf8")
